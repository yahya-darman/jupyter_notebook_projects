# %%
from IPython.display import HTML

html_code = """
<div style="width: 90%; margin: 0 auto; padding: 20px; border: 2px solid #ccc; border-radius: 10px; background-color: #2199c3;height: 50px">
    <h1 style="text-align: center; color: #c32148; ; padding-bottom: 10px; border-radius: 8px;">Heart Disease Prediciton</h1>

    </div>
"""

HTML(html_code)
# Out:
# <div style="width: 90%; margin: 0 auto; padding: 20px; border: 2px solid #ccc; border-radius: 10px; background-color: #2199c3;height: 50px">
#     <h1 style="text-align: center; color: #c32148; ; padding-bottom: 10px; border-radius: 8px;">Heart Disease Prediciton</h1>
#
#     </div>

# %% [markdown]
# ### Attribute Information
#
# - **Age**: Age in years
# - **Sex**: Gender (1 = male; 0 = female)
# - **CP**: Chest pain type
# - **TRESTBPS**: Resting blood pressure (in mm Hg, measured upon hospital admission)
# - **CHOL**: Serum cholesterol level (in mg/dl)
# - **FPS**: Fasting blood sugar greater than 120 mg/dl (1 = true; 0 = false)
# - **RESTECH**: Resting electrocardiographic results
# - **THALACH**: Maximum heart rate achieved
# - **EXANG**: Exercise-induced angina (1 = yes; 0 = no)
# - **OLDPEAK**: ST depression induced by exercise, relative to rest
# - **SLOPE**: Slope of the peak exercise ST segment
# - **CA**: Number of major coronary vessels (0-3) colored by fluoroscopy
# - **THAL**: Thalassemia type (3 = normal; 6 = fixed defect; 7 = reversible defect)
# - **TARGET**: Presence of heart disease (1 = disease present; 0 = no disease)

# %% [markdown]
# # DataSet Terms Explanation
#
# **1. Age:**
# As people get older, their risk of heart disease increases. Aging can cause changes in the heart and blood vessels, such as plaque buildup in the arteries (atherosclerosis), raising the likelihood of heart attacks and other heart problems.
#
# **2. Gender:**
# Men generally have a higher risk of heart disease at younger ages. After menopause, women's risk increases and eventually matches that of men. Estrogen, present in women before menopause, may help protect against heart disease. Women are also more likely to have unusual symptoms of heart disease, which can sometimes delay diagnosis and treatment.
#
# **3. Chest Pain Type:**
# Different types of chest pain can indicate different causes. Stable angina occurs during physical activity or stress and is relieved by rest. Unstable angina can happen at rest and may signal a more serious condition like a heart attack.
#
# **4. Resting Blood Pressure:**
# High blood pressure is a major risk factor for heart disease. It can damage arteries over time, increasing the chance of plaque buildup and causing the heart to work harder, which could lead to heart failure, heart attacks, or strokes.
#
# **5. Serum Cholesterol:**
# High levels of LDL ("bad") cholesterol and low levels of HDL ("good") cholesterol increase the risk of heart disease. LDL can form plaque in the arteries, narrowing them and restricting blood flow to the heart.
#
# **6. Fasting Blood Sugar:**
# High fasting blood sugar can point to diabetes or prediabetes, both of which are significant risk factors for heart disease. Diabetes speeds up plaque buildup in the arteries, raising the risk of heart attacks and strokes.
#
# **7. Resting Electrocardiographic Results (Resting ECG):**
# An abnormal ECG can indicate heart problems like coronary artery disease, arrhythmias, or heart muscle issues. Specific ECG patterns, such as ST-segment changes, can show signs of a heart attack.
#
# **8. Maximum Heart Rate Achieved:**
# The highest heart rate reached during exercise tests can indicate cardiovascular fitness. A lower maximum heart rate could suggest reduced heart function and a higher risk of heart disease.
#
# **9. Exercise Induced Angina:**
# Angina caused by exercise suggests coronary artery disease. It occurs when the heart doesn’t get enough oxygen and blood during physical activity, signaling a potential heart attack risk.
#
# **10. ST Depression Induced by Exercise:**
# ST-segment depression during exercise suggests reduced blood flow to the heart (myocardial ischemia). This is a strong indicator of coronary artery disease and an increased risk of heart attack.
#
# **11. Slope of Peak Exercise ST Segment:**
# The shape of the ST segment during exercise tests gives more information about the severity of reduced blood flow to the heart. A downsloping ST segment often signals significant coronary artery disease and a higher risk of heart issues.
#
# **12. Number of Major Vessels Colored by Fluoroscopy:**
# This measures how many major coronary arteries have significant narrowing, detected by fluoroscopy. More narrowed vessels indicate more severe coronary artery disease and a higher risk of heart attack.
#
# **13. Thalassemia Type:**
# Thalassemia is a genetic disorder affecting hemoglobin production. Some types, particularly thalassemia major, can cause heart problems like cardiomyopathy (a disease of the heart muscle) and heart failure.
#
# **14. Heart Disease (Target):**
# This refers to the presence or absence of heart disease, including conditions like coronary artery disease or heart attacks. The other factors listed help determine the risk of heart disease and guide diagnosis and treatment for patients.

# %% [markdown]
# ## Causes of Heart Attack
#
# 1. **Aging**: As individuals age, the risk of developing heart-related issues increases due to changes in the heart and blood vessels.
#
# 2. **Hypertension (High Blood Pressure)**: High blood pressure damages the arteries over time, increasing the risk of atherosclerosis and heart attack.
#
# 3. **High Cholesterol Levels**: Elevated levels of LDL cholesterol ("bad" cholesterol) contribute to the formation of arterial plaques, narrowing the arteries and increasing the risk of heart attack.
#
# 4. **Diabetes**: Diabetes accelerates the development of atherosclerosis and increases the risk of heart attack and other cardiovascular complications.
#
# 5. **Obesity**: Excess body weight, particularly abdominal obesity, is associated with hypertension, diabetes, and dyslipidemia, all of which are major risk factors for heart attack.
#
# 6. **Sedentary Lifestyle**: Lack of physical activity contributes to obesity, hypertension, and dyslipidemia, increasing the risk of heart attack.
#
# 7. **Smoking**: Tobacco smoke contains chemicals that damage blood vessels and promote atherosclerosis, significantly increasing the risk of heart attack.
#
# 8. **Genetic Factors**: Family history of heart disease and genetic predispositions can increase the likelihood of developing heart attack risk factors such as hypertension, high cholesterol, and diabetes.
#
# 9. **Unhealthy Diet**: Poor dietary habits high in saturated fats, trans fats, cholesterol, and sodium contribute to hypertension, dyslipidemia, obesity, and diabetes, all of which increase heart attack risk.
#
# 10. **Stress**: Chronic stress can lead to unhealthy coping mechanisms such as overeating, smoking, and physical inactivity, exacerbating heart attack risk factors.
#
# 11. **Alcohol Consumption**: Excessive alcohol consumption can raise blood pressure, contribute to obesity, and increase triglyceride levels, all of which are associated with higher heart attack risk.
#
# 12. **Sleep Apnea**: Sleep apnea is associated with hypertension, obesity, and insulin resistance, all of which increase the risk of heart attack.
#
# 13. **Poor Dental Health**: Gum disease (periodontitis) has been linked to an increased risk of heart disease and heart attack due to the inflammation and bacterial infections it causes.
#
# 14. **Drug Abuse**: Illicit drug use, particularly stimulants like cocaine and methamphetamine, can cause arterial spasms, increased heart rate, and elevated blood pressure, raising the risk of heart attack.
#
# 15. **Undiagnosed or Untreated Heart Conditions**: Conditions such as coronary artery disease, arrhythmias, heart valve disorders, and congenital heart defects can significantly increase the risk of heart attack if left untreated or undiagnosed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import logging

# Suppress warnings to keep the output clean
import warnings as wr
wr.filterwarnings("ignore")

# Sci-Kit Learn imports for machine learning
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# ===================================================================
# Removed After Model Training & Hyperparameter Tuning Stage
# =====================================================================

# Importing additional classifiers and models (commented out after training and tuning)
# from sklearn.model_selection import train_test_split

# Logistic Regression
# from sklearn.linear_model import LogisticRegression

# Decision Tree Classifier
# from sklearn.tree import DecisionTreeClassifier

# Ensemble methods
# from sklearn.ensemble import (
#     RandomForestClassifier,
#     GradientBoostingClassifier,
#     AdaBoostClassifier,
#     BaggingClassifier
# )

# Support Vector Machine (SVM)
# from sklearn.svm import SVC

# K-Nearest Neighbors
# from sklearn.neighbors import KNeighborsClassifier

# Multinomial Naive Bayes
# from sklearn.naive_bayes import MultinomialNB

# Neural Networks
# from sklearn.neural_network import MLPClassifier

# Extra Trees Classifier
# from sklearn.ensemble import ExtraTreesClassifier

# %%
# Set up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Create a logger instance
logger = logging.getLogger()

# Example usage of the logger
logger.info("Logging setup complete.")

# %%
import kagglehub
import pandas as pd
import logging

# Initialize logger
logger = logging.getLogger()
logging.basicConfig(level=logging.INFO)

# Create a loading data function
def load_data():
    """
    Load the dataset from Kaggle using kagglehub.
    """
    try:
        # Download the dataset
        path = kagglehub.dataset_download("nareshbhat/health-care-data-set-on-heart-attack-possibility")
        logger.info(f"Dataset downloaded successfully to {path}")

        # Load the data into a DataFrame
        file_path = path + "/heart.csv"  # Adjust the filename if necessary
        data = pd.read_csv(file_path)
        logger.info(f"Data loaded successfully with shape {data.shape}")

        return data
    except Exception as e:
        # Log error if something goes wrong
        logger.error(f"Error loading dataset: {e}")
        return None

# Load the data
df = load_data()

# Check if the data is loaded successfully
if df is not None:
    # Create a backup of the data for future use
    backup = df.copy()
    # Display the first few rows of the dataframe
    print(df.head())
else:
    logger.error("Data loading failed. Exiting script.")
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Number of features excluding the 'target' column
num_features = len(df.columns) - 1
print("Number of features (excluding 'target'):", num_features)

# Extract the third row where 'target' equals 1
row_with_target_1 = df[df['target'] == 1].iloc[2]
print(row_with_target_1)

# Get the total number of columns in the dataframe
total_columns = len(df.columns)
print("Total number of columns:", total_columns)
# Out:
# Number of features (excluding 'target'): 13
# age          41.0
# sex           0.0
# cp            1.0
# trestbps    130.0
# chol        204.0
# fbs           0.0
# restecg       0.0
# thalach     172.0
# exang         0.0
# oldpeak       1.4
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 2, dtype: float64
# Total number of columns: 14

# %% [markdown]
# *Data Loading*

# %%
# New descriptive column names
new_names = [
    'Age', 'Gender', 'Chest Pain Type', 'Resting Blood Pressure',
    'Serum Cholesterol', 'Fasting Blood Sugar', 'Resting ECG Results',
    'Maximum Heart Rate', 'Exercise Induced Angina', 'ST Depression',
    'Slope of ST Segment', 'Number of Major Vessels', 'Thalassemia Type', 'Target'
]

# Get the current column names
old_names = df.columns.tolist()

# Create a mapping of old column names to new column names
column_name_mapping = {old_name: new_name for old_name, new_name in zip(old_names, new_names)}

# Rename the columns in the dataframe
df.rename(columns=column_name_mapping, inplace=True)

# Print to verify the changes
print("Columns renamed successfully!")
print(df.columns)
# Out:
# Columns renamed successfully!
# Index(['Age', 'Gender', 'Chest Pain Type', 'Resting Blood Pressure',
#        'Serum Cholesterol', 'Fasting Blood Sugar', 'Resting ECG Results',
#        'Maximum Heart Rate', 'Exercise Induced Angina', 'ST Depression',
#        'Slope of ST Segment', 'Number of Major Vessels', 'Thalassemia Type',
#        'Target'],
#       dtype='object')

# %%
# Display the first few rows of the DataFrame
print("First 5 Rows of the DataFrame:\n")
print(df.head())

# Display a concise summary of the DataFrame
print("\nDataFrame Info:\n")
df.info()
# Out:
# First 5 Rows of the DataFrame:
#
#    Age  Gender  Chest Pain Type  Resting Blood Pressure  Serum Cholesterol  \
# 0   63       1                3                     145                233
# 1   37       1                2                     130                250
# 2   41       0                1                     130                204
# 3   56       1                1                     120                236
# 4   57       0                0                     120                354
#
#    Fasting Blood Sugar  Resting ECG Results  Maximum Heart Rate  \
# 0                    1                    0                 150
# 1                    0                    1                 187
# 2                    0                    0                 172
# 3                    0                    1                 178
# 4                    0                    1                 163
#
#    Exercise Induced Angina  ST Depression  Slope of ST Segment  \
# ...

# %% [markdown]
# Data Visualization

# %%
def has_categorical_column(df):
    """
    Check if the DataFrame has at least one categorical column.

    Parameters:
        df (pd.DataFrame): The DataFrame to check.

    Returns:
        bool: True if there is at least one categorical column, False otherwise.
    """
    # Iterate through all columns to check for 'object' dtype
    for col in df.columns:
        if df[col].dtype == 'object':
            return True
    return False

# Example usage
if has_categorical_column(df):
    print("The DataFrame contains at least one categorical column.")
else:
    print("The DataFrame does not contain any categorical column.")
# Out:
# The DataFrame does not contain any categorical column.

# %%
def plot_df(df):
    """
    Generate distribution plots for numerical columns and count plots for categorical columns in a DataFrame.

    Parameters:
        df (pd.DataFrame): The DataFrame to visualize.
    """
    # Select numerical and categorical columns
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    categorical_cols = df.select_dtypes(include=['object']).columns

    # Plot histograms for numerical columns
    for col in numerical_cols:
        plt.figure(figsize=(10, 6))
        sns.histplot(df[col], kde=True, color="skyblue", bins=30)
        plt.title(f"Distribution Plot of '{col}'", fontsize=14)
        plt.xlabel(col, fontsize=12)
        plt.ylabel("Frequency", fontsize=12)
        plt.xticks(rotation=45)
        plt.grid(visible=True, linestyle='--', alpha=0.6)
        plt.show()

    # Plot count plots for categorical columns
    for col in categorical_cols:
        plt.figure(figsize=(10, 6))
        sns.countplot(x=col, data=df, palette="pastel")
        plt.title(f"Count Plot of '{col}'", fontsize=14)
        plt.xlabel(col, fontsize=12)
        plt.ylabel("Count", fontsize=12)
        plt.xticks(rotation=45)
        plt.grid(visible=True, linestyle='--', alpha=0.6)
        plt.show()

# Call the function with the DataFrame
plot_df(df)

# %%
# Check for missing values
missing_values = df.isna().sum()
print("Missing Values Per Column:\n", missing_values)

# Check for duplicate rows
duplicate_count = df.duplicated().sum()
print("\nNumber of Duplicate Rows:", duplicate_count)
# Out:
# Missing Values Per Column:
#  Age                        0
# Gender                     0
# Chest Pain Type            0
# Resting Blood Pressure     0
# Serum Cholesterol          0
# Fasting Blood Sugar        0
# Resting ECG Results        0
# Maximum Heart Rate         0
# Exercise Induced Angina    0
# ST Depression              0
# Slope of ST Segment        0
# Number of Major Vessels    0
# Thalassemia Type           0
# Target                     0
# dtype: int64
#
# Number of Duplicate Rows: 1

# %%
# Generate and display a heatmap for the correlation matrix
plt.figure(figsize=(10, 6))
correlation = df.corr()

sns.heatmap(
    correlation,
    annot=True,  # Display correlation values on the heatmap
    cmap='coolwarm',  # Use the 'coolwarm' color palette for better contrast
    linewidths=1,  # Add grid lines between cells
    fmt='.2f',  # Format values to 2 decimal places
    robust=True  # Avoid color scale distortion by outliers
)

plt.title("Correlation Heatmap", fontsize=16)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Chest Pain Type', 'Resting Blood Pressure',
#        'Serum Cholesterol', 'Fasting Blood Sugar', 'Resting ECG Results',
#        'Maximum Heart Rate', 'Exercise Induced Angina', 'ST Depression',
#        'Slope of ST Segment', 'Number of Major Vessels', 'Thalassemia Type',
#        'Target'],
#       dtype='object')

# %%
# Calculate absolute correlations with the 'target' column
correlation_with_target = correlation['Target'].abs()

# Sort the correlations in descending order and extract the top 3 (excluding 'target' itself)
top_3_correlations = correlation_with_target.sort_values(ascending=False).head(4)[1:]

# Get the column names of the top 3 correlated features
top_3_columns = top_3_correlations.index.tolist()

# Output the result
print("Top 3 columns with highest correlation with the target:")
print(top_3_columns)
# Out:
# Top 3 columns with highest correlation with the target:
# ['Exercise Induced Angina', 'Chest Pain Type', 'ST Depression']

# %%
# Renaming columns in the DataFrame for better readability and understanding.
# The original dataset might have column names that are cryptic or unclear,
# so we assign meaningful names to make the data easier to work with.
# - 'Age': Patient's age in years.
# - 'Gender': Patient's gender (1 = male, 0 = female).
# - 'Chest Pain Type': Type of chest pain experienced by the patient.
# - 'Resting Blood Pressure': Resting blood pressure (in mm Hg).
# - 'Serum Cholesterol': Serum cholesterol level (in mg/dl).
# - 'Fasting Blood Sugar': Whether fasting blood sugar > 120 mg/dl (1 = true, 0 = false).
# - 'Resting ECG Results': Results of resting electrocardiographic test.
# - 'Maximum Heart Rate': Maximum heart rate achieved.
# - 'Exercise Induced Angina': Whether exercise-induced angina is present (1 = yes, 0 = no).
# - 'ST Depression': ST depression induced by exercise relative to rest.
# - 'Slope of ST Segment': Slope of the peak exercise ST segment.
# - 'Number of Major Vessels': Number of major vessels (0-3) colored by fluoroscopy.
# - 'Thalassemia Type': Type of thalassemia (blood disorder).
# - 'target': Diagnosis of heart disease (1 = presence, 0 = absence).

df.columns = ['Age', 'Gender', 'Chest Pain Type', 'Resting Blood Pressure', 'Serum Cholesterol',
              'Fasting Blood Sugar', 'Resting ECG Results', 'Maximum Heart Rate',
              'Exercise Induced Angina', 'ST Depression', 'Slope of ST Segment',
              'Number of Major Vessels', 'Thalassemia Type', 'target']

# Displaying the first few rows of the dataset to verify the changes.
df.head()
# Out:
#    Age  Gender  Chest Pain Type  Resting Blood Pressure  Serum Cholesterol  \
# 0   63       1                3                     145                233
# 1   37       1                2                     130                250
# 2   41       0                1                     130                204
# 3   56       1                1                     120                236
# 4   57       0                0                     120                354
#
#    Fasting Blood Sugar  Resting ECG Results  Maximum Heart Rate  \
# 0                    1                    0                 150
# 1                    0                    1                 187
# 2                    0                    0                 172
# 3                    0                    1                 178
# 4                    0                    1                 163
#
#    Exercise Induced Angina  ST Depression  Slope of ST Segment  \
# ...

# %%
# Importing RobustScaler to scale features while handling outliers using median and IQR.
from sklearn.preprocessing import RobustScaler

# Splitting the dataset into features (X) and target (y).
X = df.drop('target', axis=1)  # Features
y = df['target']  # Target

# Initializing and applying RobustScaler to scale the features.
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# Checking the shape of the scaled data to verify the transformation.
X_scaled.shape

# Splitting the data into training and testing sets (80% train, 20% test).
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Checking the shape of the training data (X_train) to verify the number of samples and features.
X_train.shape
# Out:
# (242, 13)

# %%
# ============================
# Model Selection
# ============================

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier,
    BaggingClassifier,
    ExtraTreesClassifier
)
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split the dataset (if not already split)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize models
models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Bagging": BaggingClassifier(),
    "SVM": SVC(probability=True),
    "KNN": KNeighborsClassifier(),
    "MLP": MLPClassifier(max_iter=500),
    "Extra Trees": ExtraTreesClassifier()
}

# Dictionary to store model performance
model_performance = {}

# Train and evaluate each model
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    # Predict on the test set
    y_pred = model.predict(X_test)
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    model_performance[model_name] = accuracy
    print(f"{model_name} Accuracy: {accuracy:.4f}")

# Find the best model
best_model_name = max(model_performance, key=model_performance.get)
best_model_score = model_performance[best_model_name]
best_model = models[best_model_name]

# Print the best model details
print("\n===================")
print(f"Best Model: {best_model_name}")
print(f"Accuracy: {best_model_score:.4f}")
print("===================")

# Example: Printing hyperparameters of the best model
if hasattr(best_model, "get_params"):
    print("\nHyperparameters of the Best Model:")
    for name, value in best_model.get_params().items():
        print(f"{name} -> {value}")
# Out:
# Logistic Regression Accuracy: 0.8525
# Decision Tree Accuracy: 0.8197
# Random Forest Accuracy: 0.8689
# Gradient Boosting Accuracy: 0.7869
# AdaBoost Accuracy: 0.8033
# Bagging Accuracy: 0.8033
# SVM Accuracy: 0.8525
# KNN Accuracy: 0.8525
# MLP Accuracy: 0.8361
# Extra Trees Accuracy: 0.8689
#
# ...
# Best Model: Random Forest
# Accuracy: 0.8689
# ...
#
# Hyperparameters of the Best Model:
# bootstrap -> True
# ccp_alpha -> 0.0
# class_weight -> None
# criterion -> gini
# max_depth -> None
# max_features -> sqrt
# max_leaf_nodes -> None
# max_samples -> None
# min_impurity_decrease -> 0.0
# min_samples_leaf -> 1
# min_samples_split -> 2
# min_weight_fraction_leaf -> 0.0
# monotonic_cst -> None
# n_estimators -> 100
# n_jobs -> None
# oob_score -> False
# random_state -> None
# verbose -> 0
# warm_start -> False

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import RobustScaler

# Initialize variables to store the best fold's metrics
best_accuracy = 0
best_fold_index = None
best_classifier = None
best_predictions = None

# Initialize the Gaussian Naive Bayes classifier
classifier = GaussianNB(priors=None, var_smoothing=1e-09)

# Set the number of folds for cross-validation
n_splits = 11

# Initialize StratifiedKFold for stratified splitting (preserves class distribution)
stratified_kfold = StratifiedKFold(n_splits=n_splits)

# Loop through each fold of cross-validation
for fold_index, (train_index, val_index) in enumerate(stratified_kfold.split(X_scaled, y)):
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_scaled[train_index], X_scaled[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Train the model on the current training fold
    classifier.fit(X_train_fold, y_train_fold)

    # Make predictions on the validation set
    y_val_pred = classifier.predict(X_val_fold)

    # Calculate and print the accuracy of the model on the validation set
    accuracy = accuracy_score(y_val_fold, y_val_pred)
    print("Accuracy on fold", fold_index + 1, ":", round(accuracy, 3))

    # Update the best accuracy if the current fold's accuracy is higher
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_fold_index = fold_index
        best_classifier = classifier
        best_predictions = y_val_pred

# Print the best fold index and its corresponding accuracy
print("Best fold index:", best_fold_index + 1)
print("Best accuracy:", round(best_accuracy, 3))

# The best_classifier, best_predictions, and best_accuracy can be used for further analysis or predictions.
# Out:
# Accuracy on fold 1 : 0.786
# Accuracy on fold 2 : 0.786
# Accuracy on fold 3 : 0.857
# Accuracy on fold 4 : 0.857
# Accuracy on fold 5 : 0.821
# Accuracy on fold 6 : 0.857
# Accuracy on fold 7 : 0.704
# Accuracy on fold 8 : 0.926
# Accuracy on fold 9 : 0.704
# Accuracy on fold 10 : 0.778
# Accuracy on fold 11 : 0.704
# Best fold index: 8
# Best accuracy: 0.926

# %% [markdown]
# Custom Predicition

# %%
# Select a sample data point (first row, excluding target column)
sample_data = df.iloc[0, :-1]

# Print feature headings (column names) and values of the sample data
print("\nFeature Headings:")
print(sample_data.index)
print("="*75)
print("Feature Values:")
print(sample_data.values)
print("="*75)

# Initialize the RobustScaler to scale the sample data
scaler = RobustScaler()

# Scale the sample data point using RobustScaler
scaled_sample_data = scaler.fit_transform(sample_data.values.reshape(1, -1))

# Make a prediction using the best trained Gaussian Naive Bayes classifier
prediction = best_classifier.predict(scaled_sample_data)

# Print the prediction with the accuracy of the model
if prediction[0] == 0:
    print(f"Prediction: No risk of heart attack with confidence {best_accuracy * 100:.3f} %")
else:
    print(f"Prediction: Possible risk of heart attack with confidence {best_accuracy * 100:.3f} %")
# Out:
# Feature Headings:
# Index(['Age', 'Gender', 'Chest Pain Type', 'Resting Blood Pressure',
#        'Serum Cholesterol', 'Fasting Blood Sugar', 'Resting ECG Results',
#        'Maximum Heart Rate', 'Exercise Induced Angina', 'ST Depression',
#        'Slope of ST Segment', 'Number of Major Vessels', 'Thalassemia Type'],
#       dtype='object')
# ...
# Feature Values:
# [ 63.    1.    3.  145.  233.    1.    0.  150.    0.    2.3   0.    0.
#    1. ]
# ...
# Prediction: Possible risk of heart attack with confidence 92.593 %
